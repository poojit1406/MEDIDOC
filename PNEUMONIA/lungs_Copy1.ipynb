# %% [markdown]
# ## Installing necessities

# %% [markdown]
# ## Data Download

# %%
# !rm chest-xray-pneumonia.zip

# %%
cd storage
# Out:
# /storage

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# ...
# 100%|█████████████████████████████████████▊| 2.29G/2.29G [00:32<00:00, 79.0MB/s]
# 100%|██████████████████████████████████████| 2.29G/2.29G [00:32<00:00, 75.0MB/s]

# %%
# !unzip chest-xray-pneumonia.zip
# Out:
# Archive:  chest-xray-pneumonia.zip
#   inflating: chest_xray/__MACOSX/._chest_xray
#   inflating: chest_xray/__MACOSX/chest_xray/._.DS_Store
#   inflating: chest_xray/__MACOSX/chest_xray/._test
#   inflating: chest_xray/__MACOSX/chest_xray/._train
#   inflating: chest_xray/__MACOSX/chest_xray/test/._.DS_Store
#   inflating: chest_xray/__MACOSX/chest_xray/test/._NORMAL
#   inflating: chest_xray/__MACOSX/chest_xray/test/._PNEUMONIA
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0001-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0003-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0005-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0006-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0007-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0009-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0010-0001.jpeg
# ...

# %% [markdown]
# ## Training Part

# %%
import glob
a = glob.glob('../chest_xray/chest_xray/train/NORMAL/*')
b = [0]*len(glob.glob('../chest_xray/chest_xray/train/NORMAL/*'))

# %%
for i in ['train','test','val']:
    a.extend(glob.glob('../chest_xray/chest_xray/'+i+'/PNEUMONIA/*'))
    b.extend([1]*len(glob.glob('../chest_xray/chest_xray/'+i+'/PNEUMONIA/*')))

# %%
d={'images':a,'severity':b}

# %%
import pandas as pd
df=pd.DataFrame( data = d )

# %%
df.to_csv('df2.csv', index = False)

# %%
import sys
sys.path.insert(0, "timm-models/pytorch-image-models/")

# %%
from fastai import *
from fastai.vision import *
from fastai.callbacks.hooks import *
import numpy as np
import pandas as pd
import timm
from functools import partial
from sklearn.model_selection import StratifiedKFold

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_everything(24)

# %%
df = pd.read_csv('df2.csv')

# %%
# df.drop(columns = ['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#                                               images  severity
# 0  ../chest_xray/chest_xray/train/NORMAL/IM-0115-...         0
# 1  ../chest_xray/chest_xray/train/NORMAL/IM-0117-...         0
# 2  ../chest_xray/chest_xray/train/NORMAL/IM-0119-...         0
# 3  ../chest_xray/chest_xray/train/NORMAL/IM-0122-...         0
# 4  ../chest_xray/chest_xray/train/NORMAL/IM-0125-...         0

# %% [markdown]
# ###Ranger

# %%
import math
import torch
from torch.optim.optimizer import Optimizer, required
import itertools as it

class Ranger(Optimizer):
    
    def __init__(self, params, lr=1e-3, alpha=0.5, k=6, N_sma_threshhold=5, betas=(.95,0.999), eps=1e-8, weight_decay=0):
        #parameter checks
        if not 0.0 <= alpha <= 1.0:
            raise ValueError(f'Invalid slow update rate: {alpha}')
        if not 1 <= k:
            raise ValueError(f'Invalid lookahead steps: {k}')
        if not lr > 0:
            raise ValueError(f'Invalid Learning Rate: {lr}')
        if not eps > 0:
            raise ValueError(f'Invalid eps: {eps}')
        
        #parameter comments:
        # beta1 (momentum) of .95 seems to work better than .90...
        #N_sma_threshold of 5 seems better in testing than 4.
        #In both cases, worth testing on your dataset (.90 vs .95, 4 vs 5) to make sure which works best for you.
        
        #prep defaults and init torch.optim base
        defaults = dict(lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
        super().__init__(params,defaults)
        
        #adjustable threshold
        self.N_sma_threshhold = N_sma_threshhold
        
        #now we can get to work...
        for group in self.param_groups:
            group["step_counter"] = 0
            #print("group step counter init")
                      
        #look ahead params
        self.alpha = alpha
        self.k = k 
        
        #radam buffer for state
        self.radam_buffer = [[None,None,None] for ind in range(10)]
        
        #lookahead weights
        self.slow_weights = [[p.clone().detach() for p in group['params']]
                                for group in self.param_groups]
        
        #don't use grad for lookahead weights
        for w in it.chain(*self.slow_weights):
            w.requires_grad = False
        
    def __setstate__(self, state):
        print("set state called")
        super(Ranger, self).__setstate__(state)
       
        
    def step(self, closure=None):
        loss = None
        #note - below is commented out b/c I have other work that passes back the loss as a float, and thus not a callable closure.  
        #Uncomment if you need to use the actual closure...
        
        #if closure is not None:
            #loss = closure()
            
        #------------ radam
        for group in self.param_groups:
    
            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad.data.float()
                if grad.is_sparse:
                    raise RuntimeError('RAdam does not support sparse gradients')
    
                p_data_fp32 = p.data.float()
    
                state = self.state[p]
    
                if len(state) == 0:
                    state['step'] = 0
                    state['exp_avg'] = torch.zeros_like(p_data_fp32)
                    state['exp_avg_sq'] = torch.zeros_like(p_data_fp32)
                else:
                    state['exp_avg'] = state['exp_avg'].type_as(p_data_fp32)
                    state['exp_avg_sq'] = state['exp_avg_sq'].type_as(p_data_fp32)
    
                exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']
                beta1, beta2 = group['betas']
    
                exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
                exp_avg.mul_(beta1).add_(1 - beta1, grad)
    
                state['step'] += 1
                buffered = self.radam_buffer[int(state['step'] % 10)]
                if state['step'] == buffered[0]:
                    N_sma, step_size = buffered[1], buffered[2]
                else:
                    buffered[0] = state['step']
                    beta2_t = beta2 ** state['step']
                    N_sma_max = 2 / (1 - beta2) - 1
                    N_sma = N_sma_max - 2 * state['step'] * beta2_t / (1 - beta2_t)
                    buffered[1] = N_sma
                    if N_sma > self.N_sma_threshhold:
                        step_size = group['lr'] * math.sqrt((1 - beta2_t) * (N_sma - 4) / (N_sma_max - 4) * (N_sma - 2) / N_sma * N_sma_max / (N_sma_max - 2)) / (1 - beta1 ** state['step'])
                    else:
                        step_size = group['lr'] / (1 - beta1 ** state['step'])
                    buffered[2] = step_size
    
                if group['weight_decay'] != 0:
                    p_data_fp32.add_(-group['weight_decay'] * group['lr'], p_data_fp32)
    
                if N_sma > 4:
                    denom = exp_avg_sq.sqrt().add_(group['eps'])
                    p_data_fp32.addcdiv_(-step_size, exp_avg, denom)
                else:
                    p_data_fp32.add_(-step_size, exp_avg)
    
                p.data.copy_(p_data_fp32)
        
        
        #---------------- end radam step
        
        #look ahead tracking and updating if latest batch = k
        for group,slow_weights in zip(self.param_groups,self.slow_weights):
            group['step_counter'] += 1
            if group['step_counter'] % self.k != 0:
                continue
            for p,q in zip(group['params'],slow_weights):
                if p.grad is None:
                    continue
                q.data.add_(self.alpha,p.data - q.data)
                p.data.copy_(q.data)
            
        
            
        return loss

# %%
tfms = get_transforms(do_flip=True,flip_vert=False, max_rotate=2.0, max_zoom=1.22, max_lighting=0.2)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in np.random.choice(df.images,20):
    img = plt.imread(i)
    print(img.shape)
# Out:
# (880, 1448)
# (1051, 1300)
# (970, 1410)
# (736, 1192)
# (752, 1280)
# (219, 527, 3)
# (813, 1176)
# (1287, 1870)
# (1008, 1480)
# (856, 1264)
# (1184, 1568)
# (1384, 1592)
# (1437, 1782)
# (856, 1048)
# (760, 920)
# (1200, 1672)
# (632, 1000)
# (1287, 1796)
# (1437, 1612)
# (760, 1000)

# %%
sz = 512
bs = 8

# %%
data = (ImageList.from_df(df=df,path='',cols='images') 
        .split_by_rand_pct(0.2)
        .label_from_df(cols='severity') 
        .transform(tfms,size=sz, padding_mode='border', resize_method=ResizeMethod.SQUISH)
        .databunch(bs=bs,num_workers=4)   
        )

# %%
data.show_batch(rows=3, figsize=(12,12))

# %%
opt=partial(Ranger)

# %%
learn = cnn_learner(data, timm.models.tf_efficientnet_b0, metrics=[FBeta(beta=1, average='macro'), accuracy],callback_fns=ShowGraph)

# %% [markdown]
# ## Training

# %%
learn.unfreeze()
learn.load('b0_stage-2-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (4685 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 0,0,0,0,0
# Path: .;
#
# Valid: LabelList (1171 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 0,1,0,0,1
# Path: .;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2dSame(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (se): SqueezeExcite(
# ...

# %%
learn.unfreeze()
learn.fit_one_cycle(10, max_lr=1e-6, callbacks=[callbacks.SaveModelCallback(learn, every='improvement', monitor='valid_loss', name='b0_stage-1-')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f_beta</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.396082</td>
#       <td>1.320713</td>
#       <td>0.400355</td>
#       <td>0.400512</td>
#       <td>06:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.250578</td>
#       <td>0.879921</td>
#       <td>0.547922</td>
#       <td>0.556789</td>
#       <td>06:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.986772</td>
#       <td>0.780151</td>
#       <td>0.613999</td>
#       <td>0.619129</td>
#       <td>06:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.954231</td>
#       <td>0.679151</td>
#       <td>0.686567</td>
#       <td>0.696840</td>
#       <td>06:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.fit(10, callbacks=[callbacks.SaveModelCallback(learn, every='improvement', monitor='accuracy', name='b0_stage-2-1'),
                                      callbacks.CSVLogger(learn, filename = 'b0_stage-2-1'),
                                     ])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f_beta</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.207290</td>
#       <td>0.179463</td>
#       <td>0.927809</td>
#       <td>0.941076</td>
#       <td>06:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.186914</td>
#       <td>0.101029</td>
#       <td>0.949325</td>
#       <td>0.959863</td>
#       <td>06:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.188690</td>
#       <td>0.125411</td>
#       <td>0.943452</td>
#       <td>0.953886</td>
#       <td>06:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.142918</td>
#       <td>0.097907</td>
#       <td>0.953819</td>
#       <td>0.963279</td>
#       <td>06:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
opt=partial(Ranger)

# %%
val = data.valid_ds.x.items[:]

# %%
# !mkdir validation

# %%
val[:20]
# Out:
# array(['./../chest_xray/chest_xray/test/NORMAL/IM-0103-0001.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person510_bacteria_2147.jpeg',
#        './../chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0561-0001.jpeg',
#        './../chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0989-0001.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person888_bacteria_2812.jpeg',
#        './../chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0923-0001.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person1098_virus_1818.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person1406_virus_2409.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person1107_virus_1831.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person1273_virus_2191.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person135_virus_271.jpeg',
#        './../chest_xray/chest_xray/train/PNEUMONIA/person1201_bacteria_3151.jpeg',
# ...

# %%
# !cp './../chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-1150-0001.jpeg' validation/

# %%
learn.load('b0_stage-2-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (4685 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 0,0,0,0,0
# Path: .;
#
# Valid: LabelList (1171 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 0,1,0,0,1
# Path: .;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2dSame(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (se): SqueezeExcite(
# ...

# %%
learn.freeze_to(-3)

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)

# %% [markdown]
# ## Inference Learner

# %%
learn.export()

# %%
# https://docs.fast.ai/tutorial.inference.html

# %% [markdown]
# ## More Training

# %%
learn.fit(5, callbacks=[callbacks.SaveModelCallback(learn, every='improvement', monitor='valid_loss', name='b0_stage-2-2'),
                                      callbacks.CSVLogger(learn, filename = 'b0_stage-2-2'),
                                     ])

# %%
learn.fit(5, callbacks=[callbacks.SaveModelCallback(learn, every='improvement', monitor='valid_loss', name='b0_stage-2-3'),
                                      callbacks.CSVLogger(learn, filename = 'b0_stage-2-3'),
                                     ])

# %%
learn.load('b0_stage-2-3')

# %%
opt=partial(Ranger)

# %%
learn.unfreeze()

# %%
lr = 3e-03

# %%
learn.fit_one_cycle(6, slice(1e-06, lr/10),wd=0.1,callbacks=[callbacks.SaveModelCallback(learn, every='improvement', monitor='accuracy', name='b0_stage-2-4'),
                                      callbacks.CSVLogger(learn, filename = 'b0_stage-2-4'),
                                     ])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f_beta</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.093331</td>
#       <td>0.459257</td>
#       <td>0.818422</td>
#       <td>0.846154</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.085982</td>
#       <td>0.454196</td>
#       <td>0.830448</td>
#       <td>0.858974</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.086098</td>
#       <td>0.440484</td>
#       <td>0.830448</td>
#       <td>0.858974</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.081983</td>
#       <td>0.475410</td>
#       <td>0.822752</td>
#       <td>0.852564</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.load('b0_stage-2-4')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (624 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# 1,1,1,1,1
# Path: .;
#
# Valid: LabelList (156 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# 0,1,1,1,2
# Path: .;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2dSame(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn1): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (se): SqueezeExcite(
# ...

# %%
learn.fit_one_cycle(6, slice(1e-07, lr/100),wd=0.1,callbacks=[callbacks.SaveModelCallback(learn, every='improvement', monitor='accuracy', name='b0_stage-2-5'),
                                      callbacks.CSVLogger(learn, filename = 'b0_stage-2-5'),
                                     ])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f_beta</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.078132</td>
#       <td>0.422106</td>
#       <td>0.841274</td>
#       <td>0.865385</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.064330</td>
#       <td>0.435987</td>
#       <td>0.846723</td>
#       <td>0.871795</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.079870</td>
#       <td>0.458666</td>
#       <td>0.830448</td>
#       <td>0.858974</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.077951</td>
#       <td>0.489805</td>
#       <td>0.822752</td>
#       <td>0.852564</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.
